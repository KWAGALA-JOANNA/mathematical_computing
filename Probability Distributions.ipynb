# %% [markdown]
# BINOMIAL DISTRIBUTION

# %%
# Binomial Distribution
# Binomial Distribution is a Discrete Distribution
# It describes the outcome of binary scenarios, eg. toss a coin


# It has three parameters
#n- number of trials
#p- probability of occurence of each trial (eg for toss of coin)
#size- the shape of the returned array

# %%
import os
import sys
os.path.dirname(sys.executable) #c:\\users\\HP\\anaconda3. this is the path where python was
#originally installed. And the path keeps on changing once the environments are activated.
# Out:
# 'c:\\Users\\HP\\AppData\\Local\\Programs\\Python\\Python311'

# %%
#Example
# Given 10 trials for coin toss to generate 10 data points:
import numpy as np
from numpy import random 

x = random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [6 5 5 5 6 4 7 5 5 3]

# %%
# Visualization of binomial distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as snc

snc.distplot(random.binomial(n=10, p=0.5, size=10000), hist=True, kde=False)

 # plt.xticks(), helps to label the x-axis ina specific range eg 2,4,6,8....etc or 5, 10, 15
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\2358409145.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   snc.distplot(random.binomial(n=10, p=0.5, size=10000), hist=True, kde=False)

# %% [markdown]
# NORMAL DISTRIBUTION

# %%
#Normal Distribution
#Generate a random distribution of size 2x3:
from numpy import random
x = random.normal(size=(2, 3))
print(x)
# Out:
# [[-0.57858306 -0.70306861 -0.65568138]
#  [-0.17362613  1.30314943 -0.07620569]]

# %%
#Example
#Generate a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2:
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))
#loc stands for mean, scale is standard deviation
print(x)
# Out:
# [[ 1.46419491  3.51969995  0.32813685]
#  [-0.86941924  3.6588364   1.50347703]]

# %%
#visualisation of normal distribution
from numpy import random
import matplotlib.pyplot as plt 
import seaborn as sns 

sns.distplot(random.normal(size=1000), hist=False) 
#false will only return  the curve
plt.show() # This will return a normal distribution curve only
sns.distplot(random.normal(size=1000), hist=True) 
#returns both the histogram and the curve.
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\2095694538.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\2095694538.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Differences between Normal and Binomial Distribution
from numpy import random
import matplotlib.pyplot as plt 
import seaborn as sns 

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\1011331943.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\1011331943.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# POISSON DISTRIBUTION

# %%
#It has two parameters:
#lam- rate or known number of occurrences eg 2 for above problem 
#lam means lambda
#size- the shape of the returned array

# %%
#Example: Generate a random 1x10 distribution for occurrences 2
from numpy import random
x = random.poisson(lam=2, size=10)
print(x)
# Out:
# [2 3 1 3 2 3 2 2 4 1]

# %%
#visualisation of poisson Distribution
from numpy import random
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.distplot(random.poisson(lam=2, size=1000), kde=False)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\3549971837.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %% [markdown]
# UNIFORM DISTRIBUTION

# %%
#Uniform distribution
#used to describe probability where every event has

# %%
#Visualisation of uniform distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.uniform(size=100), hist= False)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1192\816512409.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=100), hist= False)

# %%
import numpy as np

# %% [markdown]
# 1. A fair coin flip produces heads

# %%
# Simulate 1 million tests of one fair coin flip remember the output
# of these tests are the successes, or heads

from numpy import random
tests = random.binomial(n=1, p=0.5, size=int(1e6))
tests
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.distplot(random.binomial(n=1, p=0.5, size=1000), hist=True, kde=False )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5104\630240776.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=1, p=0.5, size=1000), hist=True, kde=False )
# <Axes: >
